# %% [markdown]
# #### Python function, that takes in a json request and output the label names along with uniqueid, text, sentiment score in a json

# %%
import json
import pandas as pd
import numpy as np
import re
import sys
import nltk
from collections import defaultdict
from nltk.corpus import stopwords, sentiwordnet as swn
from nltk.stem import WordNetLemmatizer
from nltk import ngrams
from sklearn.feature_extraction.text import TfidfVectorizer
from stopwords_list import stop_words_list
from sklearn.decomposition import LatentDirichletAllocation
import collections
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import json
from textblob import TextBlob, Word

# %% [markdown]
# Data preprocessing

# %%
f = open('Response.json') 
df1=json.load(f)
keys_to_extract = ["uniqueId", "text"]
new=[]

for i in range (0,len(df1['responseList'])):
    d=[{key: df1['responseList'][i][key] for key in keys_to_extract}]
    a=pd.DataFrame.from_dict(d) 
    new.append(a)
df=pd.concat(new, ignore_index=True)

# %% [markdown]
# Call function 'topic_modelling with **dataframe** and **no.of topic** to be generated'

# %%
def topic_modelling(df,n):
    

    # case text as lowercase, remove punctuation, remove extra whitespace in string and on both sides of string
    df['remove_lower_punct'] = df['text'].str.lower().str.replace("'", '').str.replace('[^\w\s]', ' ').str.replace(" \d+", " ").str.replace(' +', ' ').str.strip()
    
    # apply sentiment analysis
    analyser = SentimentIntensityAnalyzer()
    
    sentiment_score_list = []
    sentiment_label_list = []

    for i in df['remove_lower_punct'].values.tolist():
        sentiment_score = analyser.polarity_scores(i)

        if sentiment_score['compound'] >= 0.05:
            sentiment_score_list.append(sentiment_score['compound'])
            sentiment_label_list.append('Positive')
        elif sentiment_score['compound'] > -0.05 and sentiment_score['compound'] < 0.05:
            sentiment_score_list.append(sentiment_score['compound'])
            sentiment_label_list.append('Neutral')
        elif sentiment_score['compound'] <= -0.05:
            sentiment_score_list.append(sentiment_score['compound'])
            sentiment_label_list.append('Negative')

    df['sentiment'] = sentiment_label_list
    df['sentiment score'] = sentiment_score_list
    
    # tokenise string
    df['tokenise'] = df.apply(lambda row: nltk.word_tokenize(row[1]), axis=1)
    # initiate stopwords from nltk
    stop_words = stopwords.words('english')
    # add additional missing terms
    stop_words.extend(stop_words_list) 
    # remove stopwords
    df['remove_stopwords'] = df['tokenise'].apply(lambda x: [item for item in x if item not in stop_words])
    
    # initiate nltk lemmatiser
    wordnet_lemmatizer = WordNetLemmatizer()
    # lemmatise words
    df['lemmatise'] = df['remove_stopwords'].apply(lambda x: [wordnet_lemmatizer.lemmatize(y) for y in x]) 
    
    # initialise the count vectorizer
    vectorizer = TfidfVectorizer(analyzer = 'word', ngram_range = (3, 4))
    # join the processed data to be vectorised
    vectors = []
    for index, row in df.iterrows():
        vectors.append(", ".join(row[6]))
    vectorised = vectorizer.fit_transform(vectors)
    
    # initisalise LDA Model
    lda_model = LatentDirichletAllocation(n_components = n, # number of topics
                                      random_state = 10,          # random state
                                      evaluate_every = -1,      # compute perplexity every n iters, default: Don't
                                      n_jobs = -1,              # Use all available CPUs
                                     )

    lda_output = lda_model.fit_transform(vectorised)
    # column names
    topic_names = [ str(i) for i in range(1, lda_model.n_components + 1)]
    # make the pandas dataframe
    df_document_topic = pd.DataFrame(np.round(lda_output, 2), columns = topic_names)
    # get dominant topic for each document
    dominant_topic = (np.argmax(df_document_topic.values, axis=1)+1)
    df_document_topic['Dominant_topic'] = dominant_topic
    # join to original dataframes
    df = pd.merge(df, df_document_topic, left_index = True, right_index = True, how = 'outer')
    
    # index names
    docnames = ['Doc' + str(i) for i in range(len(df))]
    # Make the pandas dataframe
    df_document_topic = pd.DataFrame(np.round(lda_output, 5), columns=topic_names, index=docnames)
    # Get dominant topic for each document
    dominant_topic = np.argmax(df_document_topic.values, axis=1)
    df_document_topic['dominant_topic'] = dominant_topic
    # Topic-Keyword Matrix
    df_topic_keywords = pd.DataFrame(lda_model.components_)
    # Assign Column and Index
    df_topic_keywords.columns = vectorizer.get_feature_names()
    df_topic_keywords.index = topic_names
    df_topic_no = pd.DataFrame(df_topic_keywords.idxmax())
    df_scores = pd.DataFrame(df_topic_keywords.max())
    tmp = pd.merge(df_topic_no, df_scores, left_index=True, right_index=True)
    tmp.columns = ['topic', 'relevance_score']
    
    all_topics = []

    for i in tmp['topic'].unique():    
        tmp_1 = tmp.loc[tmp['topic'] == i].reset_index()
        tmp_1 = tmp_1.sort_values('relevance_score', ascending=False).head(1)

        tmp_1['topic'] = int(tmp_1['topic']) 

        tmp_2 = []
        tmp_2.append(tmp_1['topic'].unique()[0])
        tmp_2.append((tmp_1['index'].unique()))
        all_topics.append(tmp_2)

    all_topics = pd.DataFrame(all_topics, columns=['Dominant_topic', 'topic_name'])
    
    df2=df[['uniqueId','text','sentiment','sentiment score','Dominant_topic']]
    frequent_features=list(''.join(i) for i in all_topics.topic_name)
    
    #absa_list is the dictionary containing all the reviews for each topic
    absa_list = dict()
    for f in frequent_features:
        # For each comment
        absa_list[f] = list()
        for comment in df.text:
            blob = TextBlob(comment)
            # For each sentence of the comment
            for sentence in blob.sentences:
                # Search for frequent feature 'f'
                q = '|'.join(f.split())
                if re.search(r'\w*(' + str(q) + ')\w*', str(sentence)):
                    absa_list[f].append(sentence)
                    
    #final dataframe with all required columns                
    final=pd.merge(df2,all_topics,on=['Dominant_topic'])
    li=[]
    res2={}
    for i,j in zip(final.Dominant_topic, final.topic_name):
    
        d={}
        a=''.join(j)
        d[a]=final[['text','uniqueId','sentiment','sentiment score']][final.Dominant_topic==i].to_dict('records')
        res2.update(d)   
        
    return res2

# %%
final_dict=topic_modelling(df,20)

# %%
final_dict
# Out:
# {'location lot amenities spacious': [{'text': 'Wonderful experience',
#    'uniqueId': '1816GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.5719},
#   {'text': 'Nice location,\nlot of amenities,spacious rooms,\nparking problem is thr..',
#    'uniqueId': '1804GOIBO',
#    'sentiment': 'Neutral',
#    'sentiment score': 0.0258},
#   {'text': 'very good property..excellent staff n hospitality.enjoyed our stay a lot.kids park n toy room added an extra perk to our little one.inside n outside decor is mesmerising.\nawsm maintainence of garden n lawn area.lots of time u can spend in the property itself..baby friendly cooking n custom made baby food is a great advantage if u r travelling with kids.',
#    'uniqueId': '1828GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9626},
#   {'text': 'great place to stay',
#    'uniqueId': '1835GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.6249},
#   {'text': 'not so good',
#    'uniqueId': '1841GOIBO',
#    'sentiment': 'Negative',
#    'sentiment score': -0.3865},
#   {'text': 'Nice location,\nlot of amenities,spacious rooms,\nparking problem is thr..',
#    'uniqueId': '1804GOIBO',
#    'sentiment': 'Neutral',
#    'sentiment score': 0.0258},
#   {'text': 'Wonderful experience',
#    'uniqueId': '1816GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.5719},
#   {'text': 'very good property..excellent staff n hospitality.enjoyed our stay a lot.kids park n toy room added an extra perk to our little one.inside n outside decor is mesmerising.\nawsm maintainence of garden n lawn area.lots of time u can spend in the property itself..baby friendly cooking n custom made baby food is a great advantage if u r travelling with kids.',
#    'uniqueId': '1828GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9626},
#   {'text': 'great place to stay',
#    'uniqueId': '1835GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.6249},
#   {'text': 'not so good',
#    'uniqueId': '1841GOIBO',
#    'sentiment': 'Negative',
#    'sentiment score': -0.3865},
#   {'text': 'Bed very uncomfortable\n',
#    'uniqueId': '1531HT',
#    'sentiment': 'Negative',
#    'sentiment score': -0.4391},
#   {'text': 'Bed very uncomfortable\n',
#    'uniqueId': '1531HT',
#    'sentiment': 'Negative',
#    'sentiment score': -0.4391}],
#  'service place nice': [{'text': 'great location...one can also drive and take your car and has ample of parking available...but make sure you convey this to hotel first. lovely food and superb service and very well behavior staffs 👍🏼 keep up the good work',
#    'uniqueId': '1817GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9758},
#   {'text': 'I loved the place. It is for sure a must visit if you are a luxury lover\nHospitality is Great.',
#    'uniqueId': '1805GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9337},
#   {'text': 'It is nice property  staff is very cooperative i would like to come here again. . great experience value of money food quality is a super nice interior well behaved staff overall experience is a superb I will strongly recommend this hotel to everyone thank you. .',
#    'uniqueId': None,
#    'sentiment': 'Positive',
#    'sentiment score': 0.9831},
#   {'text': 'great service   the place is really kept up nice and well  definitely attention to detail has been given  almost everything is immaculate. .',
#    'uniqueId': None,
#    'sentiment': 'Positive',
#    'sentiment score': 0.8993},
#   {'text': 'It is nice property  staff is very cooperative i would like to come here again. . great experience value of money food quality is a super nice interior well behaved staff overall experience is a superb I will strongly recommend this hotel to everyone thank you.',
#    'uniqueId': None,
#    'sentiment': 'Positive',
#    'sentiment score': 0.9831},
#   {'text': 'I loved the place. It is for sure a must visit if you are a luxury lover\nHospitality is Great.',
#    'uniqueId': '1805GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9337},
#   {'text': 'great location...one can also drive and take your car and has ample of parking available...but make sure you convey this to hotel first. lovely food and superb service and very well behavior staffs 👍🏼 keep up the good work',
#    'uniqueId': '1817GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9758},
#   {'text': "Top notch service and quality, needs better wifi It's a Mayfair property so high standards on quality and service is expected and delivered. The best part of the stay was the staff which was helpful and on the toes. Special mention for the service staff at the buffet restaurant and the spa. Things that can be improved significantly is a) the wifi connection as it is very patchy and not at all reliable. b) The bathroom hot water supply is via a single unit of Geyser hence inadequate if you are staying at the property in winter. Overall lots of entertainment and activity is arranged by the property and evenings are quite buzzing.   ",
#    'uniqueId': '1532HT',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9485},
#   {'text': "Top notch service and quality, needs better wifi It's a Mayfair property so high standards on quality and service is expected and delivered. The best part of the stay was the staff which was helpful and on the toes. Special mention for the service staff at the buffet restaurant and the spa. Things that can be improved significantly is a) the wifi connection as it is very patchy and not at all reliable. b) The bathroom hot water supply is via a single unit of Geyser hence inadequate if you are staying at the property in winter. Overall lots of entertainment and activity is arranged by the property and evenings are quite buzzing.   ",
#    'uniqueId': '1532HT',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9485}],
#  'staff super efficient': [{'text': 'Beautiful place . Super staff who are super efficient and courteous.  Loved my stay',
#    'uniqueId': '1818GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9709},
#   {'text': 'A very wonderful property.The room was luxurious,the service was splendid and the view from our room was beautiful.Overall everything was good and would love to come back again.',
#    'uniqueId': '1807GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9628},
#   {'text': 'Excellent Property  Very Prime Location Extremely professional   Courteos Hotel Staff made my Family trip memorable  Extremely delicious food  Will always stay with Mayfair. . great service   the place is really kept up nice and well  definitely attention to detail has been given  almost everything is immaculate. .',
#    'uniqueId': None,
#    'sentiment': 'Positive',
#    'sentiment score': 0.9621},
#   {'text': 'Excellent hotel, good location, courteous staff. Two things which did not go well for me: 1) Mattress was soft / more like had lived its life and 2) the treadmill and cycle in gym were not in operation',
#    'uniqueId': '1827GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.8974},
#   {'text': 'Located near Mall road, opposite Governor House, its an excellent property for family leisure trips. Good hospitality, courteous staff and sumptuous food - what more one wants. Sheer luxury in abundance. Opt for villas on top floor they provide excellent view from balcony.',
#    'uniqueId': '1843GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9371},
#   {'text': 'A very wonderful property.The room was luxurious,the service was splendid and the view from our room was beautiful.Overall everything was good and would love to come back again.',
#    'uniqueId': '1807GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9628},
#   {'text': 'Excellent Property  Very Prime Location Extremely professional   Courteos Hotel Staff made my Family trip memorable  Extremely delicious food  Will always stay with Mayfair. .',
#    'uniqueId': None,
#    'sentiment': 'Positive',
#    'sentiment score': 0.8268},
#   {'text': 'Beautiful place . Super staff who are super efficient and courteous.  Loved my stay',
#    'uniqueId': '1818GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9709},
#   {'text': 'Excellent hotel, good location, courteous staff. Two things which did not go well for me: 1) Mattress was soft / more like had lived its life and 2) the treadmill and cycle in gym were not in operation',
#    'uniqueId': '1827GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.8974},
#   {'text': 'Located near Mall road, opposite Governor House, its an excellent property for family leisure trips. Good hospitality, courteous staff and sumptuous food - what more one wants. Sheer luxury in abundance. Opt for villas on top floor they provide excellent view from balcony.',
#    'uniqueId': '1843GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9371},
#   {'text': "Great place to stay.  It is like a little resort.  I got a shave, hair cut.  Food is great.  You can't fgo wrong with staying here.",
#    'uniqueId': '1544HT',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9033},
#   {'text': "Great place to stay.  It is like a little resort.  I got a shave, hair cut.  Food is great.  You can't fgo wrong with staying here.",
#    'uniqueId': '1544HT',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9033}],
#  'inter activitie staff': [{'text': 'it was good experience and nice inter activitie staff',
#    'uniqueId': '1819GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.6908},
#   {'text': 'Thanks for the warm welcome It was beautiful experience at Mayfair. Room was beautifully organised very clean and food was too yummy.',
#    'uniqueId': '1808GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9674},
#   {'text': 'The best anyone can find to stay. Everything looks great. Food, staff, welcoming, location and flowers in particular are great. Room has almost everything that we require. And great views from the room window. The best stay we ever had. I would love to see them again soon. Thank you.',
#    'uniqueId': '1848GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9853},
#   {'text': 'Thanks for the warm welcome It was beautiful experience at Mayfair. Room was beautifully organised very clean and food was too yummy.',
#    'uniqueId': '1808GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9674},
#   {'text': 'it was good experience and nice inter activitie staff',
#    'uniqueId': '1819GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.6908},
#   {'text': 'The best anyone can find to stay. Everything looks great. Food, staff, welcoming, location and flowers in particular are great. Room has almost everything that we require. And great views from the room window. The best stay we ever had. I would love to see them again soon. Thank you.',
#    'uniqueId': '1848GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9853},
#   {'text': 'An amazing stay. Have only praises for the staff to make it a memorable stay. Property is excellent with old world charm and beautifully maintained interiors and garden. ',
#    'uniqueId': '1533HT',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9538},
#   {'text': 'An amazing stay. Have only praises for the staff to make it a memorable stay. Property is excellent with old world charm and beautifully maintained interiors and garden. ',
#    'uniqueId': '1533HT',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9538}],
#  'lovely attentive staff': [{'text': 'great hotel awesome surroundings very helpful staff and food quality was good.',
#    'uniqueId': '1820GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9348},
#   {'text': 'great hotel awesome surroundings very helpful staff and food quality was good.',
#    'uniqueId': '1820GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9348},
#   {'text': 'Amazing HotelIts an amazing property and maintained immaculately topped by the excellent services!',
#    'uniqueId': '1535HT',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9062},
#   {'text': 'Comfortable in Darjeeling Lovely well-located property. Provided a takeaway breakfast because of our early departure without our even requesting it.  Good WIFI.  very enjoyable and would stay again.',
#    'uniqueId': '1547HT',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9359},
#   {'text': 'Lovely attentive staff. the property is well kept with many family activities.',
#    'uniqueId': '1548HT',
#    'sentiment': 'Positive',
#    'sentiment score': 0.7096},
#   {'text': 'Amazing HotelIts an amazing property and maintained immaculately topped by the excellent services!',
#    'uniqueId': '1535HT',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9062},
#   {'text': 'Comfortable in Darjeeling Lovely well-located property. Provided a takeaway breakfast because of our early departure without our even requesting it.  Good WIFI.  very enjoyable and would stay again.',
#    'uniqueId': '1547HT',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9359},
#   {'text': 'Lovely attentive staff. the property is well kept with many family activities.',
#    'uniqueId': '1548HT',
#    'sentiment': 'Positive',
#    'sentiment score': 0.7096}],
#  'time good ambience comfort': [{'text': 'one of the best in darjeeling. awesome experience and lovely hospitality...the best. thank u for your services.',
#    'uniqueId': '1806GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9628},
#   {'text': 'had a great time with good ambience and comfort',
#    'uniqueId': '1822GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.8591},
#   {'text': 'I wish they could make their buffet breakfast more lavish and give more choices',
#    'uniqueId': '1850GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.4019},
#   {'text': 'one of the best in darjeeling. awesome experience and lovely hospitality...the best. thank u for your services.',
#    'uniqueId': '1806GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9628},
#   {'text': 'had a great time with good ambience and comfort',
#    'uniqueId': '1822GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.8591},
#   {'text': 'I wish they could make their buffet breakfast more lavish and give more choices',
#    'uniqueId': '1850GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.4019}],
#  'its good experience': [{'text': 'very nice property and decent location, nice supporting staff',
#    'uniqueId': '1809GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.8313},
#   {'text': 'The hotel has a coffee shop, kids room and all sorts of amenities have been provided. Service of the staff is commendable. Location of the hotel is also noteworthy. Decor of the hotel with its grandeur has won my heart. Food quality and variety is excellent. I would love to recommend this hotel to others who look for luxury and leisure',
#    'uniqueId': '1829GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9709},
#   {'text': 'Its a good Experience. Hotel services and the food quality everything was fine. Its really a good experience. Location is very good and convenient. Hotel is well suitable for business class and for travelers.',
#    'uniqueId': '1845GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9036},
#   {'text': 'very nice property and decent location, nice supporting staff',
#    'uniqueId': '1809GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.8313},
#   {'text': 'The hotel has a coffee shop, kids room and all sorts of amenities have been provided. Service of the staff is commendable. Location of the hotel is also noteworthy. Decor of the hotel with its grandeur has won my heart. Food quality and variety is excellent. I would love to recommend this hotel to others who look for luxury and leisure',
#    'uniqueId': '1829GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9709},
#   {'text': 'Its a good Experience. Hotel services and the food quality everything was fine. Its really a good experience. Location is very good and convenient. Hotel is well suitable for business class and for travelers.',
#    'uniqueId': '1845GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9036},
#   {'text': 'Staff was very polite and courteous. They were willing to aaccomodate on demand order.  Food was delicious. Excellent service!',
#    'uniqueId': '1541HT',
#    'sentiment': 'Positive',
#    'sentiment score': 0.8876},
#   {'text': 'Staff was very polite and courteous. They were willing to aaccomodate on demand order.  Food was delicious. Excellent service!',
#    'uniqueId': '1541HT',
#    'sentiment': 'Positive',
#    'sentiment score': 0.8876}],
#  'amazing hotel stay': [{'text': 'Amenities were very good. Great staff attitude. Views were pleasant. Location was convenient ( walkable from the Darjeeling Mall). Wonderful experience all in all',
#    'uniqueId': '1810GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.939},
#   {'text': 'amazing hotel... must stay with your family',
#    'uniqueId': '1834GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.5859},
#   {'text': 'Amenities were very good. Great staff attitude. Views were pleasant. Location was convenient ( walkable from the Darjeeling Mall). Wonderful experience all in all',
#    'uniqueId': '1810GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.939},
#   {'text': 'amazing hotel... must stay with your family',
#    'uniqueId': '1834GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.5859},
#   {'text': 'Excellent staff , bright and colourful environment with lots of flowers , gardens and with nice view to mountain.',
#    'uniqueId': '1540HT',
#    'sentiment': 'Positive',
#    'sentiment score': 0.8555},
#   {'text': 'Excellent staff , bright and colourful environment with lots of flowers , gardens and with nice view to mountain.',
#    'uniqueId': '1540HT',
#    'sentiment': 'Positive',
#    'sentiment score': 0.8555}],
#  'rooms designed properly': [{'text': 'rooms everything designed properly, very good heritage property.\nbut my room no 301 bathroom always smells bad.\nfood both dinner n breakfast too good and lots of variety.',
#    'uniqueId': '1801GOIBO',
#    'sentiment': 'Negative',
#    'sentiment score': -0.3825},
#   {'text': 'Location is decent; quality of ammenties is good too but service is extremely poor..one is not informed about the limited availability of hot water at check-in and it is even worse to find that out in the midst of a bath...i have personally have no issues with limited supply of hot watee but should have been informed and the service recovery time was pathetic...',
#    'uniqueId': '1849GOIBO',
#    'sentiment': 'Negative',
#    'sentiment score': -0.9654},
#   {'text': 'Very good place to stay  Very well built  clean  coloful place with lots of amenities like pool  gym  carrom  kids play area etc  The place is full of nice and coloful flowers  It looks stunningly beautiful in evening lights  Rooms are super awesome  built like classic English style  Price well worth spending it. . best hotel in Darjeeling  way ahead of Darjeeling standards u will be amazed to see their quality of service truly outstanding. .',
#    'uniqueId': None,
#    'sentiment': 'Positive',
#    'sentiment score': 0.9932},
#   {'text': 'rooms everything designed properly, very good heritage property.\nbut my room no 301 bathroom always smells bad.\nfood both dinner n breakfast too good and lots of variety.',
#    'uniqueId': '1801GOIBO',
#    'sentiment': 'Negative',
#    'sentiment score': -0.3825},
#   {'text': 'Very good place to stay  Very well built  clean  coloful place with lots of amenities like pool  gym  carrom  kids play area etc  The place is full of nice and coloful flowers  It looks stunningly beautiful in evening lights  Rooms are super awesome  built like classic English style  Price well worth spending it. . best hotel in Darjeeling  way ahead of Darjeeling standards u will be amazed to see their quality of service truly outstanding. .',
#    'uniqueId': None,
#    'sentiment': 'Positive',
#    'sentiment score': 0.9932},
#   {'text': 'Location is decent; quality of ammenties is good too but service is extremely poor..one is not informed about the limited availability of hot water at check-in and it is even worse to find that out in the midst of a bath...i have personally have no issues with limited supply of hot watee but should have been informed and the service recovery time was pathetic...',
#    'uniqueId': '1849GOIBO',
#    'sentiment': 'Negative',
#    'sentiment score': -0.9654}],
#  'attentive staff fantastic': [{'text': 'Food quality , hospitality and services excellent,Room sizes small',
#    'uniqueId': '1802GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.5719},
#   {'text': 'It was satisfying stay. Excellent food, courteous staff,help with smile!',
#    'uniqueId': '1823GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9349},
#   {'text': 'Food quality , hospitality and services excellent,Room sizes small',
#    'uniqueId': '1802GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.5719},
#   {'text': 'It was satisfying stay. Excellent food, courteous staff,help with smile!',
#    'uniqueId': '1823GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9349},
#   {'text': 'Great hotel, super attentive staff and overall fantastic experience.',
#    'uniqueId': '1546HT',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9118},
#   {'text': 'Great hotel, super attentive staff and overall fantastic experience.',
#    'uniqueId': '1546HT',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9118}],
#  '100 minute check': [{'text': 'super hyped property with uneven guest treatment policy,they treat guest very unevenly . I booked executive room with ... rupees after reaching the hotel I found they have provided me a dormitory . I am compelled to change my room and take a room with ...plus taxes extra. In the name of executive room they sell all sort rooms . Wow  are you guys fooling customers .There are few more short comings regarding this hotel and administration .Not happy at all providing two stars .',
#    'uniqueId': '1803GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.7719},
#   {'text': 'super hyped property with uneven guest treatment policy,they treat guest very unevenly . I booked executive room with ... rupees after reaching the hotel I found they have provided me a dormitory . I am compelled to change my room and take a room with ...plus taxes extra. In the name of executive room they sell all sort rooms . Wow  are you guys fooling customers .There are few more short comings regarding this hotel and administration .Not happy at all providing two stars .',
#    'uniqueId': '1803GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.7719},
#   {'text': 'Beautiful hotel with spectacular views and central location in Darjeeling.  Service was excellent especially our dining room waiter Tapan.  The food that was served was always tasty and the bar in the hotel was very comfortable.  Staff were able to arrange transportation to and from Bagdogra airport as well as a driver for a day of touring the area.',
#    'uniqueId': '1542HT',
#    'sentiment': 'Positive',
#    'sentiment score': 0.923},
#   {'text': 'Pricey but clean and well maintained. The hotel did add random additional charges (~$100) at the last minute during check-in which was not mentioned at the time of booking through expedia.',
#    'uniqueId': '1545HT',
#    'sentiment': 'Positive',
#    'sentiment score': 0.5499},
#   {'text': 'Beautiful hotel with spectacular views and central location in Darjeeling.  Service was excellent especially our dining room waiter Tapan.  The food that was served was always tasty and the bar in the hotel was very comfortable.  Staff were able to arrange transportation to and from Bagdogra airport as well as a driver for a day of touring the area.',
#    'uniqueId': '1542HT',
#    'sentiment': 'Positive',
#    'sentiment score': 0.923},
#   {'text': 'Pricey but clean and well maintained. The hotel did add random additional charges (~$100) at the last minute during check-in which was not mentioned at the time of booking through expedia.',
#    'uniqueId': '1545HT',
#    'sentiment': 'Positive',
#    'sentiment score': 0.5499}],
#  'cozy place stay': [{'text': 'excellent location and one of the only few property in darjeeling with such fantastic views and proximity with the city centre. The Hospitality was also outstanding and ambience and artefacts of the property were charming. All of these summed up a perfect holiday',
#    'uniqueId': '1811GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9702},
#   {'text': 'nice hotel , good spacious rooms but view from room was bad as it was facing a dumping ground . expected good mountai non view room',
#    'uniqueId': '1826GOIBO',
#    'sentiment': 'Negative',
#    'sentiment score': -0.25},
#   {'text': 'Nice and cozy place to stay',
#    'uniqueId': '1851GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.4215},
#   {'text': 'i liked the ambiance of the hotel It is such a great place to relax in Darjeeling. Everything is at a high standard, and we were never disappointed at any time with any aspect of the hotel or the service.Having breakfast in the dining room looking out across the mountains was an unforgettable experience....hotel staff and services are of a great quality and location of the hotel is also very well located and which is very convenient....',
#    'uniqueId': '1847GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9574},
#   {'text': 'excellent location and one of the only few property in darjeeling with such fantastic views and proximity with the city centre. The Hospitality was also outstanding and ambience and artefacts of the property were charming. All of these summed up a perfect holiday',
#    'uniqueId': '1811GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9702},
#   {'text': 'nice hotel , good spacious rooms but view from room was bad as it was facing a dumping ground . expected good mountai non view room',
#    'uniqueId': '1826GOIBO',
#    'sentiment': 'Negative',
#    'sentiment score': -0.25},
#   {'text': 'i liked the ambiance of the hotel It is such a great place to relax in Darjeeling. Everything is at a high standard, and we were never disappointed at any time with any aspect of the hotel or the service.Having breakfast in the dining room looking out across the mountains was an unforgettable experience....hotel staff and services are of a great quality and location of the hotel is also very well located and which is very convenient....',
#    'uniqueId': '1847GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9574},
#   {'text': 'Nice and cozy place to stay',
#    'uniqueId': '1851GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.4215},
#   {'text': 'Nice cute hotel with great hospitality Excellent stay. . . . . . .',
#    'uniqueId': None,
#    'sentiment': 'Positive',
#    'sentiment score': 0.9274},
#   {'text': 'Nice cute hotel with great hospitality Excellent stay. . . . . . .',
#    'uniqueId': None,
#    'sentiment': 'Positive',
#    'sentiment score': 0.9274}],
#  'hotel nice location': [{'text': 'It was wonderful stay.Everything was good.Staff was very friendly and helpful.Food was tasty .Hassle free check in .During this pandemic situation they are taking utmost care of their guests.I appreciate for their concern towards their guests.It was exquisite experience',
#    'uniqueId': '1812GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9696},
#   {'text': 'Wonderful hotel with nice location. Hospitality is great',
#    'uniqueId': '1830GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.891},
#   {'text': 'Very good it was owesone stay staff was very coperative',
#    'uniqueId': '1825GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.4927},
#   {'text': 'It was wonderful stay.Everything was good.Staff was very friendly and helpful.Food was tasty .Hassle free check in .During this pandemic situation they are taking utmost care of their guests.I appreciate for their concern towards their guests.It was exquisite experience',
#    'uniqueId': '1812GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9696},
#   {'text': 'Very good it was owesone stay staff was very coperative',
#    'uniqueId': '1825GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.4927},
#   {'text': 'Wonderful hotel with nice location  Hospitality is great. .',
#    'uniqueId': None,
#    'sentiment': 'Positive',
#    'sentiment score': 0.891},
#   {'text': 'Staff are nice but more laid back than most places. But they remember guests and try to personalize the experience.  The property is a good place to relax after a busy day. ',
#    'uniqueId': '1534HT',
#    'sentiment': 'Positive',
#    'sentiment score': 0.8625},
#   {'text': 'Staff are nice but more laid back than most places. But they remember guests and try to personalize the experience.  The property is a good place to relax after a busy day. ',
#    'uniqueId': '1534HT',
#    'sentiment': 'Positive',
#    'sentiment score': 0.8625}],
#  'wow viewssuch unique hotel': [{'text': "it was an okay experience for us. beautiful place bt it took us an hour to reach with our bike though we were only at 10 mins distance at all the time. google map doesn't give you exact location and the no. given on the booking voucher wasn't responded even once so it ruined the start of the day. later on, i was there to celebrate my fiance birthday which i wanted to be a surprise, so when i received the confirmation call a day ago i requested to decorate the room and they said they would bt i had to mail my request so i did. on arrival i enquired about the room they said its being ready and they will talk to head chef about it. nothing was done.. so overall, it was just a stay on a beautiful place without a beautiful service.\nno problem was faced as a couple.",
#    'uniqueId': '1813GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.8918},
#   {'text': 'VERY BED HOTEL NO ANY CONTACT NO. IN HOTELS AND NOT GENIUNE PERSON IN HOTEL MAYFAIR DARJELLING NO ANY RESPONSIBLE PERSON IN HOTEL MERI ADVANCE BOOKING KO HOTEL MANAGEMENT NE ROOM AVAILABLE NHI HAI BOL DIYA THIS IS NOT HOTEL POLICY MERE SATH 2 CHILDRENS BHI THE. MAIN BAHUT PARESHAN HUA. .....',
#    'uniqueId': '1836GOIBO',
#    'sentiment': 'Negative',
#    'sentiment score': -0.7799},
#   {'text': "it was an okay experience for us. beautiful place bt it took us an hour to reach with our bike though we were only at 10 mins distance at all the time. google map doesn't give you exact location and the no. given on the booking voucher wasn't responded even once so it ruined the start of the day. later on, i was there to celebrate my fiance birthday which i wanted to be a surprise, so when i received the confirmation call a day ago i requested to decorate the room and they said they would bt i had to mail my request so i did. on arrival i enquired about the room they said its being ready and they will talk to head chef about it. nothing was done.. so overall, it was just a stay on a beautiful place without a beautiful service.\nno problem was faced as a couple.",
#    'uniqueId': '1813GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.8918},
#   {'text': 'VERY BED HOTEL NO ANY CONTACT NO. IN HOTELS AND NOT GENIUNE PERSON IN HOTEL MAYFAIR DARJELLING NO ANY RESPONSIBLE PERSON IN HOTEL MERI ADVANCE BOOKING KO HOTEL MANAGEMENT NE ROOM AVAILABLE NHI HAI BOL DIYA THIS IS NOT HOTEL POLICY MERE SATH 2 CHILDRENS BHI THE. MAIN BAHUT PARESHAN HUA. .....',
#    'uniqueId': '1836GOIBO',
#    'sentiment': 'Negative',
#    'sentiment score': -0.7799},
#   {'text': 'Wow at the viewsSuch a unique hotel in design and location. A must stay place if you visit Darjeeling. ',
#    'uniqueId': '1539HT',
#    'sentiment': 'Positive',
#    'sentiment score': 0.5859},
#   {'text': 'Excellent facilitates , ambience , good food Lovely location, friendly staff , fantastic spread for breakfast ',
#    'uniqueId': '1549HT',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9531},
#   {'text': 'Wow at the viewsSuch a unique hotel in design and location. A must stay place if you visit Darjeeling. ',
#    'uniqueId': '1539HT',
#    'sentiment': 'Positive',
#    'sentiment score': 0.5859},
#   {'text': 'Excellent facilitates , ambience , good food Lovely location, friendly staff , fantastic spread for breakfast ',
#    'uniqueId': '1549HT',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9531}],
#  'well maintained food delicious': [{'text': 'Well maintained  Food is very delicious  Staffs are very cordial. .',
#    'uniqueId': None,
#    'sentiment': 'Positive',
#    'sentiment score': 0.7264},
#   {'text': 'Well maintained  Food is very delicious  Staffs are very cordial. .',
#    'uniqueId': None,
#    'sentiment': 'Positive',
#    'sentiment score': 0.7264},
#   {'text': 'Receiving the good and room service is very nice and morning breakfast is so many items and very items very nice quantity and also room quantity very nice with flower garden nice the overall Mayfair hotel and recode  Darjeeling  good',
#    'uniqueId': '1538HT',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9527},
#   {'text': 'Receiving the good and room service is very nice and morning breakfast is so many items and very items very nice quantity and also room quantity very nice with flower garden nice the overall Mayfair hotel and recode  Darjeeling  good',
#    'uniqueId': '1538HT',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9527}],
#  'staff to top chef': [{'text': "Very nice property. Excellent location. Great food. Very courteous staff. To top it all, the Chef, ATANU, takes care of each guest during the meals. Our 3 days stay couldn't get better",
#    'uniqueId': '1821GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9541},
#   {'text': "Very nice property. Excellent location. Great food. Very courteous staff. To top it all, the Chef, ATANU, takes care of each guest during the meals. Our 3 days stay couldn't get better",
#    'uniqueId': '1821GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9541},
#   {'text': 'Absolutely wonderful!What an amazing experience! They have done an absolutely fabulous job of maintaining this property that has been around since the 1800s. Location is unbeatable just a short walk to a wonderful observation point of the Himalayan mountain range and also the mall area full of locap merchants and shops.  This location is also away from the congested and polluted downtown area.  \nService was impeccable, from a wonderful welcoming with tea and cookies to lightimg the fireplace in the room anytime requested. Also appreciated was complimentary unlimited bottled water and tea/snacks.  They helped arrange our tiger hill transport, airport transports and a half day tour -- certainly if trying to save money can do these on your own own but we knew it would be done well through the hotel.\nResort grounds were very well maintained with gorgeous flowers abundant.\nBreakfast and dinners were delicious, with both indian and western items available.  The weakness was baked goods and desserts which wouldnt measure up to a standard western palate, but there was plenty to choose from.\nOnly other minor complaint was cold rooms but this was easily remedied with room heater and fireplace.\n\nOverall this was magical stay for us and would hoghly recommend to anyone able to stay at the property.',
#    'uniqueId': '1537HT',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9825},
#   {'text': 'Absolutely wonderful!What an amazing experience! They have done an absolutely fabulous job of maintaining this property that has been around since the 1800s. Location is unbeatable just a short walk to a wonderful observation point of the Himalayan mountain range and also the mall area full of locap merchants and shops.  This location is also away from the congested and polluted downtown area.  \nService was impeccable, from a wonderful welcoming with tea and cookies to lightimg the fireplace in the room anytime requested. Also appreciated was complimentary unlimited bottled water and tea/snacks.  They helped arrange our tiger hill transport, airport transports and a half day tour -- certainly if trying to save money can do these on your own own but we knew it would be done well through the hotel.\nResort grounds were very well maintained with gorgeous flowers abundant.\nBreakfast and dinners were delicious, with both indian and western items available.  The weakness was baked goods and desserts which wouldnt measure up to a standard western palate, but there was plenty to choose from.\nOnly other minor complaint was cold rooms but this was easily remedied with room heater and fireplace.\n\nOverall this was magical stay for us and would hoghly recommend to anyone able to stay at the property.',
#    'uniqueId': '1537HT',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9825}],
#  'food good tasty': [{'text': 'Hotel is good but food is not good and it is not tasty and exhorbhitantly costly',
#    'uniqueId': '1824GOIBO',
#    'sentiment': 'Negative',
#    'sentiment score': -0.4135},
#   {'text': 'Hotel is good but food is not good and it is not tasty and exhorbhitantly costly',
#    'uniqueId': '1824GOIBO',
#    'sentiment': 'Negative',
#    'sentiment score': -0.4135}],
#  'zone play lovely statues': [{'text': "Mayfair Darjeeling is very beautiful and lovely once you enter it but to get to it you'll have to drive down a steep road which is kind of scary, and you at least expect a property like Mayfair to be situated in a better location. But on the inside, it is fabulous. The rooms are nice, I don't remember the one we stayed in but I remember paying a hell lot (almost 14,000) and the room wasn't even that lavish. It is way too over priced. The buffet dinner and breakfast was okay, nothing great, a lot of variety but the taste was pretty bland, not praise worthy. The library is really nice though. And they even have a collection of DVDs, which you can take to your room and watch. I liked this facility a lot.\nI think you could try other hotels if you're ready to pay this much! You could stay here if you happen to find some good deals and get it for cheaper rates. Totally not worth paying this much though.",
#    'uniqueId': '1852GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9385},
#   {'text': 'As recommended by many, this is one of the Best Hotel in Darjeeling. The entry to the Hotel oddly starts with a descent from the Main entrance gate but into the Paradise walking by the side of small temple, flowers all around, kids zone to play and then lovely statues and going past the flowers and sit out area to our nice Cottage. Everything in this hotel in warm and elegant  with an Old English style Decor giving us a perfect stay to relax and unwind overlooking the Darjeeling city from within and outside the room. The restaurant have a good selection & Quality of both Veg and Non Veg dish',
#    'uniqueId': '1846GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9928},
#   {'text': 'As recommended by many, this is one of the Best Hotel in Darjeeling. The entry to the Hotel oddly starts with a descent from the Main entrance gate but into the Paradise walking by the side of small temple, flowers all around, kids zone to play and then lovely statues and going past the flowers and sit out area to our nice Cottage. Everything in this hotel in warm and elegant  with an Old English style Decor giving us a perfect stay to relax and unwind overlooking the Darjeeling city from within and outside the room. The restaurant have a good selection & Quality of both Veg and Non Veg dish',
#    'uniqueId': '1846GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9928},
#   {'text': "Mayfair Darjeeling is very beautiful and lovely once you enter it but to get to it you'll have to drive down a steep road which is kind of scary, and you at least expect a property like Mayfair to be situated in a better location. But on the inside, it is fabulous. The rooms are nice, I don't remember the one we stayed in but I remember paying a hell lot (almost 14,000) and the room wasn't even that lavish. It is way too over priced. The buffet dinner and breakfast was okay, nothing great, a lot of variety but the taste was pretty bland, not praise worthy. The library is really nice though. And they even have a collection of DVDs, which you can take to your room and watch. I liked this facility a lot.\nI think you could try other hotels if you're ready to pay this much! You could stay here if you happen to find some good deals and get it for cheaper rates. Totally not worth paying this much though.",
#    'uniqueId': '1852GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9385}],
#  'wonderful place stay good': [{'text': 'The service and food was upto the mark all the staff verymuch cooperative and well behaved.',
#    'uniqueId': '1842GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.2732},
#   {'text': 'I am in love with MAYFAIR ... the best service ever..\nI celebrated my daughters birthday in Mayfair and it was a dream come true...\nLove your service and love you guyz',
#    'uniqueId': '1844GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9783},
#   {'text': 'The service and food was upto the mark all the staff verymuch cooperative and well behaved.',
#    'uniqueId': '1842GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.2732},
#   {'text': 'I am in love with MAYFAIR ... the best service ever..\nI celebrated my daughters birthday in Mayfair and it was a dream come true...\nLove your service and love you guyz',
#    'uniqueId': '1844GOIBO',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9783},
#   {'text': 'Wonderful place to stay Good and service were great. I would definitely come back to Mayfair if I ever visit Darjeeling again.',
#    'uniqueId': '1536HT',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9246},
#   {'text': 'Nice and Comfortable! The hotel was really nice along with friendly staff and good food. Great location to make multiple family pics! ',
#    'uniqueId': '1543HT',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9606},
#   {'text': 'Wonderful place to stay Good and service were great. I would definitely come back to Mayfair if I ever visit Darjeeling again.',
#    'uniqueId': '1536HT',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9246},
#   {'text': 'Nice and Comfortable! The hotel was really nice along with friendly staff and good food. Great location to make multiple family pics! ',
#    'uniqueId': '1543HT',
#    'sentiment': 'Positive',
#    'sentiment score': 0.9606}]}
